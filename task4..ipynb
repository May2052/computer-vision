# %%
import cv2

# %%
import numpy

# %%
cap1=cv2.imread("v.jpg")

# %%
cap=cv2.imread("v3.jpg")

# %%
cap2=numpy.hstack((cap,cap1))

# %%
cv2.imshow("pic",cap2)
cv2.waitKey()==13
cv2.destroyAllWindows()

# %%
import cv2

# %%
import numpy

# %%
pic=numpy.zeros((500,700,3))

# %%
pic[:,:]=[0,255,0]
pic[100:104,250:450]=[0,0,0]
pic[100:284,250:254]=[0,0,0]
pic[100:200,450:454]=[0,0,0]
pic[200:204,250:550]=[0,0,0]
pic[200:280,550:554]=[0,0,0]
pic[280:284,250:554]=[0,0,0]
pic[100:200,348:352]=[0,0,0]

# %%
pic[204:280,254:550]=[255,0,0]
pic[104:200,352:450]=[0,0,255]
pic[104:200,254:348]=[0,0,255]

# %%
pic[280:284,280:320]=[255,255,255]
pic[280:284,480:520]=[255,255,255]

# %%
center_coordinates = (500,282)
radius = 20
color = (0,0,0)
thickness = -1
pic = cv2.circle( pic,center_coordinates, radius, color, thickness)

center_coordinates = (300,282)
radius = 20
color = (0,0,0)
thickness = -1
pic = cv2.circle( pic,center_coordinates, radius, color, thickness)

# %%
cv2.imshow("hello",pic)
cv2.waitKey()
cv2.destroyAllWindows()

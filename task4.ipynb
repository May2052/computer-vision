# %%
import cv2

# %%
cap1=cv2.imread("v.jpg")

# %%
cap1.shape
# Out:
# (400, 400, 3)

# %%
cv2.imshow("pic",cap1)
cv2.waitKey()==13
cv2.destroyAllWindows()

# %%
cap=cv2.imread("v3.jpg")

# %%
cap.shape
# Out:
# (400, 400, 3)

# %%
cv2.imshow("pic",cap)
cv2.waitKey()==13
cv2.destroyAllWindows()

# %%
cap1[0:400,200:400]=cap[0:400,200:400]

# %%
cv2.imshow("pic",cap1)
cv2.waitKey()==13
cv2.destroyAllWindows()
